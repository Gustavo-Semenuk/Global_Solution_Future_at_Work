-- %% [markdown]
-- ## Dicionário dos Dados:
--
-- - ano = Ano
-- - sigla_uf = Sigla da Unidade da Federação
-- - expectativa_vida = Expectativa de Vida
-- - fecundidade_total = Fecundidade Total
-- - mortalidade_1 = Mortalidade Infantil até 1 Ano
-- - mortalidade_5 = Mortalidade Infantil até 5 Anos
-- - razao_dependencia = Percentual da população de menos de 15 anos e da população de 65 anos e mais em relação à população de 15 a 64 anos
-- - prob_sobrevivencia_40 = Probabilidade de sobrevivência até 40 anos
-- - prob_sobrevivencia_60 = Probabilidade de sobrevivência até 60 anos
-- - taxa_envelhecimento = Taxa de envelhecimento
-- - expectativa_anos_estudo = Expectativa de anos de estudo aos 18 anos de idade
-- - taxa_analfabetismo_11_a_14 = Taxa de analfabetismo da população de 11 a 14 anos de idade
-- - taxa_analfabetismo_15_a_17 = Taxa de analfabetismo da população de 15 a 17 anos de idade
-- - taxa_analfabetismo_15_mais = Taxa de analfabetismo da população de 15 anos ou mais de idade
-- - taxa_analfabetismo_18_a_24 = Taxa de analfabetismo da população de 18 a 24 anos de idade
-- - taxa_analfabetismo_18_mais = Taxa de analfabetismo da população de 18 anos ou mais de idade
-- - taxa_analfabetismo_25_a_29 = Taxa de analfabetismo da população de 25 a 29 anos de idade
-- - taxa_analfabetismo_25_mais = Taxa de analfabetismo da população de 25 anos ou mais de idade
-- - taxa_atraso_0_basico = Percentual da população de 6 a 17 anos de idade frequentando o ensino básico que não tem atraso idade-série
-- - taxa_atraso_0_fundamental = Percentual da população de 6 a 14 anos de idade frequentando o ensino fundamental que não tem atraso idade-série
-- - taxa_atraso_0_medio = Percentual da população de 15 a 17 anos de idade frequentando o ensino médio que não tem atraso idade-série
-- - taxa_atraso_1_basico = Percentual da população de 6 a 17 anos de idade frequentando o ensino básico que tem 1 ano de atraso idade-série
-- - taxa_atraso_1_fundamental = Percentual da população de 6 a 14 anos de idade frequentando o ensino fundamental que tem 1 ano de atraso idade-série
-- - taxa_atraso_1_medio = Percentual da população de 15 a 17 anos de idade frequentando o ensino médio que tem 1 ano de atraso idade-série
-- - taxa_atraso_2_basico = Percentual da população de 6 a 17 anos de idade frequentando o ensino básico que tem 2 anos ou mais de atraso idade-série
-- - taxa_atraso_2_fundamental = Percentual da população de 6 a 14 anos de idade frequentando o ensino fundamental que tem 2 anos ou mais de atraso idade-série
-- - taxa_atraso_2_medio = Percentual da população de 15 a 17 anos de idade frequentando o ensino médio que tem 2 anos de atraso idade-série
-- - taxa_freq_bruta_basico = Taxa de frequência bruta ao ensino básico
-- - taxa_freq_bruta_fundamental = Taxa de frequência bruta ao ensino fundamental
-- - taxa_freq_bruta_medio = Taxa de frequência bruta ao ensino médio
-- - taxa_freq_bruta_pre = Taxa de frequência bruta à pré-escola
-- - taxa_freq_bruta_superior = Taxa de frequência bruta ao ensino superior
-- - taxa_freq_liquida_basico = Taxa de frequência líquida ao ensino básico
-- - taxa_freq_liquida_fundamental = Taxa de frequência líquida ao ensino fundamental
-- - taxa_freq_liquida_medio = Taxa de frequência líquida ao ensino médio
-- - taxa_freq_liquida_pre = Taxa de frequência líquida à pré-escola
-- - taxa_freq_liquida_superior = Taxa de frequência líquida ao ensino superior
-- - taxa_freq_0_3 = Taxa de atendimento escolar da população de 0 a 3 anos de idade
-- - taxa_freq_11_14 = Taxa de atendimento escolar da população de 11 a 14 anos de idade
-- - taxa_freq_15_17 = Taxa de atendimento escolar da população de 15 a 17 anos de idade
-- - taxa_freq_18_24 = Taxa de atendimento escolar da população de 18 a 24 anos de idade
-- - taxa_freq_25_29 = Taxa de atendimento escolar da população de 25 a 29 anos de idade
-- - taxa_freq_4_5 = Taxa de atendimento escolar da população de 4 a 5 anos de idade
-- - taxa_freq_4_6 = Percentual da população de 4 a 6 anos de idade frequentando a escola
-- - taxa_freq_5_6 = Percentual da população de 5 a 6 anos de idade frequentando a escola
-- - taxa_freq_6 = Taxa de atendimento escolar da população de 6 anos de idade
-- - taxa_freq_6_14 = Taxa de atendimento escolar da população de 6 a 14 anos de idade
-- - taxa_freq_6_17 = Taxa de atendimento escolar da população de 6 a 17 anos de idade
-- - taxa_freq_fundamental_15_17 = Percentual da população de 15 a 17 anos de idade frequentando o ensino fundamental
-- - taxa_freq_fundamental_18_24 = Percentual da população de 18 a 24 anos de idade frequentando o ensino fundamental
-- - taxa_freq_fundamental_4_5 = Percentual da população de 4 a 5 anos de idade frequentando o ensino fundamental
-- - taxa_freq_medio_18_24 = Percentual da população de 18 a 24 anos de idade frequentando o ensino médio
-- - taxa_freq_medio_6_14 = Percentual da população de 6 a 14 anos de idade frequentando o ensino médio
-- - taxa_freq_superior_15_17 = Percentual da população de 15 a 17 anos de idade frequentando o ensino superior
-- - taxa_fundamental_11_13 = Percentual da população de 11 a 13 anos de idade frequentando os anos finais do fundamental ou que já concluiu o fundamental
-- - taxa_fundamental_12_14 = Percentual da população de 12 a 14 anos de idade frequentando os anos finais do fundamental ou que já concluiu o fundamental
-- - taxa_fundamental_15_17 = Percentual da população de 15 a 17 anos com fundamental completo
-- - taxa_fundamental_16_18 = Percentual da população de 16 a 18 anos de idade com o ensino fundamental completo
-- - taxa_fundamental_18_24 = Percentual da população de 18 a 24 anos com fundamental completo
-- - taxa_fundamental_18_mais = Percentual da população de 18 anos ou mais com fundamental completo
-- - taxa_fundamental_25_mais = Percentual da população de 25 anos ou mais com fundamental completo
-- - taxa_medio_18_20 = Percentual da população de 18 a 20 anos de idade com o ensino médio completo
-- - taxa_medio_18_24 = Percentual da população de 18 a 24 anos com ensino médio completo
-- - taxa_medio_18_mais = Percentual da população de 18 anos ou mais com ensino médio completo
-- - taxa_medio_19_21 = Percentual da população de 19 a 21 anos de idade com o ensino médio completo
-- - taxa_medio_25_mais = Percentual da população de 25 anos ou mais com ensino médio incompleto
-- - taxa_superior_25_mais = Percentual da população de 25 anos ou mais com superior completo
-- - renda_pc_max_quintil_1 = Renda domiciliar per capita máxima do quinto mais pobre
-- - renda_pc_max_quintil_2 = Renda domiciliar per capita máxima do 2º quinto mais pobre
-- - renda_pc_max_quintil_3 = Renda domiciliar per capita máxima do 3º quinto mais pobre
-- - renda_pc_max_quintil_4 = Renda domiciliar per capita máxima do 4º quinto mais pobre
-- - renda_pc_max_decil_9 = Renda domiciliar per capita mínima do décimo mais rico
-- - indice_gini = Índice de Gini
-- - prop_pobreza_extrema = Proporção de extremamente pobres
-- - prop_pobreza_extrema_criancas = Proporção de crianças extremamente pobres
-- - prop_pobreza = Proporção de pobres
-- - prop_pobreza_criancas = Proporção de crianças pobres
-- - prop_vulner_pobreza = Proporção de vulneráveis à pobreza
-- - prop_vulner_pobreza_criancas = Proporção de crianças vulneráveis à pobreza
-- - prop_renda_10_ricos = Percentual da renda total apropriada pelos 10% mais ricos
-- - prop_renda_20_pobres = Percentual da renda total apropriada pelos 20% mais pobres
-- - prop_renda_20_ricos = Percentual da renda total apropriada pelos 20% mais ricos
-- - prop_renda_40_pobres = Percentual da renda total apropriada pelos 40% mais pobres
-- - prop_renda_60_pobres = Percentual da renda total apropriada pelos 60% mais pobres
-- - prop_renda_80_pobres = Percentual da renda total apropriada pelos 80% mais pobres
-- - prop_renda_trabalho = Percentual da renda proveniente de rendimentos do trabalho
-- - razao_10_ricos_40_pobres = Razão 10% mais ricos / 40% mais pobres
-- - razao_20_ricos_40_pobres = Razão 20% mais ricos / 40% mais pobres
-- - renda_pc = Renda per capita média
-- - renda_pc_quintil_1 = Renda domiciliar per capita média do quinto mais pobre
-- - renda_pc_decil_10 = Renda domiciliar per capita média do décimo mais rico
-- - renda_pc_quintil_2 = Renda domiciliar per capita média do 2º quinto mais pobre
-- - renda_pc_quintil_3 = Renda domiciliar per capita média do 3º quinto mais pobre
-- - renda_pc_quintil_4 = Renda domiciliar per capita média do 4º quinto mais pobre
-- - renda_pc_quintil_5 = Renda domiciliar per capita média do quinto mais rico
-- - renda_pc_exc_renda_nula = Renda domiciliar per capita média, exceto renda nula
-- - renda_pc_pobreza_extrema = Renda domiciliar per capita média dos extremamente pobres
-- - renda_pc_pobreza = Renda domiciliar per capita média dos pobres
-- - renda_pc_vulner_pobreza = Renda domiciliar per capita média dos vulneráveis à pobreza
-- - indice_theil = Índice de Theil - L
-- - prop_trabalhadores_conta_proria = Percentual de ocupados de 18 anos ou mais que são trabalhadores por conta própria
-- - prop_empregadores = Percentual de ocupados de 18 anos ou mais que são empregadores
-- - prop_ocupados_agropecuaria = Percentual dos ocupados no setor agropecuário
-- - prop_ocupados_comercio = Percentual dos ocupados no setor comércio
-- - prop_ocupados_construcao = Percentual dos ocupados no setor de construção
-- - prop_ocupados_extracao = Percentual dos ocupados no setor extrativo mineral
-- - prop_ocupados_formalizacao = Grau de formalização do trabalho das pessoas ocupadas
-- - prop_ocupados_fundamental = Percentual dos ocupados com fundamental completo
-- - prop_ocupados_medio = Percentual dos ocupados com médio completo
-- - prop_ocupados_servicos = Percentual dos ocupados no setor serviços
-- - prop_ocupados_siup = Percentual dos ocupados nos setores de serviços industriais de utilidade pública
-- - prop_ocupados_superior = Percentual dos ocupados com superior completo
-- - prop_ocupados_transformacao = Percentual dos ocupados na indústria de transformação
-- - prop_ocupados_renda_0 = Percentual dos ocupados sem rendimento
-- - prop_ocupados_renda_1_sm = Percentual dos ocupados com rendimento de até 1 salário mínimo
-- - prop_ocupados_renda_2_sm = Percentual dos ocupados com rendimento de até 2 salários mínimos
-- - prop_ocupados_renda_3_sm = Percentual dos ocupados com rendimento de até 3 salários mínimo
-- - prop_ocupados_renda_5_sm = Percentual dos ocupados com rendimento de até 5 salários mínimo
-- - renda_media_ocupados = Rendimento médio dos ocupados
-- - taxa_atividade = Taxa de atividade das pessoas de 10 anos ou mais de idade
-- - taxa_atividade_10_14 = Taxa de atividade das pessoas de 10 a 14 anos de idade
-- - taxa_atividade_15_17 = Taxa de atividade das pessoas de 15 a 17 anos de idade
-- - taxa_atividade_18_24 = Taxa de atividade das pessoas de 18 a 24 anos de idade
-- - taxa_atividade_18_mais = Taxa de atividade das pessoas de 18 anos ou mais de idade
-- - taxa_atividade_25_29 = Taxa de atividade das pessoas de 25 a 29 anos de idade
-- - taxa_desocupacao = Taxa de desocupação da população de 10 anos ou mais de idade
-- - taxa_desocupacao_10_14 = Taxa de desocupação da população de 10 a 14 anos de idade
-- - taxa_desocupacao_15_17 = Taxa de desocupação da população de 15 a 17 anos de idade
-- - taxa_desocupacao_18_24 = Taxa de desocupação da população de 18 a 24 anos de idade
-- - taxa_desocupacao_18_mais = Taxa de desocupação da população de 18 anos ou mais de idade
-- - taxa_desocupacao_25_29 = Taxa de desocupação da população de 25 a 29 anos de idade
-- - indice_treil_trabalho = Índice de Theil-L dos rendimentos do trabalho
-- - taxa_ocupados_carteira = Percentual de ocupados de 18 anos ou mais que são empregados com carteira
-- - taxa_ocupados_setor_publico = Percentual de ocupados de 18 anos ou mais que são trabalhadores do setor público
-- - taxa_ocupados_sem_carteira = Percentual de ocupados de 18 anos ou mais que são empregados sem carteira
-- - taxa_agua_encanada = Percentual da população que vive em domicílios com água encanada
-- - taxa_banheiro_agua_encanada = Percentual da população que vive em domicílios com banheiro e água encanada
-- - taxa_densidade_2_mais = Percentual da população que vive em domicílios com densidade superior a 2 pessoas por dormitório
-- - taxa_coleta_lixo = Percentual da população que vive em domicílios urbanos com serviço de coleta de lixo
-- - taxa_energia_eletrica = Percentual da população que vive em domicílios com energia elétrica
-- - taxa_agua_esgoto_inadequados = Percentual de pessoas em domicílios com abastecimento de água e esgotamento sanitário inadequados
-- - taxa_paredes_inadequados = Percentual de pessoas em domicílios com paredes que não sejam de alvenaria ou madeira aparelhada
-- - taxa_criancas_dom_sem_fund = Percentual de crianças que vivem em domicílios em que nenhum dos moradores tem o ensino fundamental completo
-- - taxa_criancas_fora_escola_4_5 = Percentual de crianças de 4 a 5 anos que não frequenta a escola
-- - taxa_criancas_fora_escola_6_14 = Percentual de crianças de 6 a 14 anos que não frequenta a escola
-- - taxa_dom_sem_fund = Percentual pessoas que vivem em domicílios em que nenhum morador tem o ensino fundamental completo
-- - taxa_dom_vulner_sem_fund = Percentual de pessoas em domicílios vulneráveis à pobreza e em que ninguém tem fundamental completo
-- - taxa_sem_fund_informal = Percentual de pessoas de 18 anos ou mais sem fundamental completo e em ocupação informal
-- - taxa_mulheres_com_filho_10_14 = Percentual de mulheres de 10 a 14 anos de idade que tiveram filhos
-- - taxa_mulheres_com_filho_15_17 = Percentual de mulheres de 15 a 17 anos de idade que tiveram filhos
-- - taxa_mulheres_chefe_filho_15m = Percentual de mães chefes de família, sem fundamental completo e com pelo menos um filho menor de 15 anos de idade
-- - taxa_nest_ntrab_vulner_15_24 = Percentual de pessoas de 15 a 24 anos que não estudam nem trabalham e são vulneráveis à pobreza
-- - taxa_vulner_desloc_1_hora = Percentual de pessoas em domicílios vulneráveis à pobreza e que gastam mais de uma hora até o trabalho
-- - taxa_dom_vulner_dep_idoso = Percentual de pessoas em domicílios vulneráveis à pobreza e dependentes de idosos
-- - taxa_sem_energia_eletrica = Percentual de pessoas em domicílios sem energia elétrica
-- - populacao_homens_0_4 = População masculina de 0 a 4 anos de idade
-- - populacao_homens_10_14 = População masculina de 10 a 14 anos de idade
-- - populacao_homens_15_19 = População masculina de 15 a 19 anos de idade
-- - populacao_homens_20_24 = População masculina de 20 a 24 anos de idade
-- - populacao_homens_25_29 = População masculina de 25 a 29 anos de idade
-- - populacao_homens_30_34 = População masculina de 30 a 34 anos de idade
-- - populacao_homens_35_39 = População masculina de 35 a 39 anos de idade
-- - populacao_homens_40_44 = População masculina de 40 a 44 anos de idade
-- - populacao_homens_45_49 = População masculina de 45 a 49 anos de idade
-- - populacao_homens_50_54 = População masculina de 50 a 54 anos de idade
-- - populacao_homens_55_59 = População masculina de 55 a 59 anos de idade
-- - populacao_homens_5_9 = População masculina de 5 a 9 anos de idade
-- - populacao_homens_60_64 = População masculina de 60 a 64 anos de idade
-- - populacao_homens_65_69 = População masculina de 65 a 69 anos de idade
-- - populacao_homens_70_74 = População masculina de 70 a 74 anos de idade
-- - populacao_homens_75_79 = População masculina de 75 a 79 anos de idade
-- - populacao_homens = População residente masculina
-- - populacao_homens_80_mais = População masculina com 80 anos e mais de idade
-- - populacao_mulheres_0_4 = População feminina de 0 a 4 anos de idade
-- - populacao_mulheres_10_14 = População feminina de 10 a 14 anos de idade
-- - populacao_mulheres_15_19 = População feminina de 15 a 19 anos de idade
-- - populacao_mulheres_20_24 = População feminina de 20 a 24 anos de idade
-- - populacao_mulheres_25_29 = População feminina de 25 a 29 anos de idade
-- - populacao_mulheres_30_34 = População feminina de 30 a 34 anos de idade
-- - populacao_mulheres_35_39 = População feminina de 35 a 39 anos de idade
-- - populacao_mulheres_40_44 = População feminina de 40 a 44 anos de idade
-- - populacao_mulheres_45_49 = População feminina de 45 a 49 anos de idade
-- - populacao_mulheres_50_54 = População feminina de 50 a 54 anos de idade
-- - populacao_mulheres_55_59 = População feminina de 55 a 59 anos de idade
-- - populacao_mulheres_5_9 = População feminina de 5 a 9 anos de idade
-- - populacao_mulheres_60_64 = População feminina de 60 a 64 anos de idade
-- - populacao_mulheres_65_69 = População feminina de 65 a 69 anos de idade
-- - populacao_mulheres_70_74 = População feminina de 70 a 74 anos de idade
-- - populacao_mulheres_75_79 = População feminina de 75 a 79 anos de idade
-- - populacao_mulheres_80_mais = População feminina com 80 anos e mais de idade
-- - populacao_mulheres = População residente feminina
-- - populacao_1_menos = População de até 1 ano de idade
-- - populacao_11_14 = População de 11 a 14 anos de idade
-- - populacao_11_13 = População de 11 a 13 anos de idade
-- - populacao_12_14 = População de 12 a 14 anos de idade
-- - populacao_1_3 = População de 1 a 3 anos de idade
-- - populacao_15_mais = População de 15 anos ou mais de idade
-- - populacao_15_17 = População de 15 a 17 anos de idade
-- - populacao_15_24 = População de 15 a 24 anos de idade
-- - populacao_16_18 = População de 16 a 18 anos de idade
-- - populacao_18_mais = População de 18 anos ou mais de idade
-- - populacao_18_20 = População de 18 a 20 anos de idade
-- - populacao_18_24 = População de 18 a 24 anos de idade
-- - populacao_19_21 = População de 19 a 21 anos de idade
-- - populacao_25_mais = População de 25 anos ou mais de idade
-- - populacao_4 = População de 4 anos de idade
-- - populacao_5 = População de 5 anos de idade
-- - populacao_6 = População de 6 anos de idade
-- - populacao_6_10 = População de 6 a 10 anos de idade
-- - populacao_6_17 = População de 6 a 17 anos de idade
-- - populacao_65_mais = População de 65 anos ou mais de idade
-- - populacao = População
-- - populacao_urbana = População urbana
-- - populacao_rural = População rural
-- - populacao_dom_pp = População total que reside em domicílios particulares permanentes
-- - populacao_dom_pp_exc_renda_nula = População total que reside em domicílios particulares permanentes, exceto os com renda nula
-- - pea = População economicamente ativa de 10 anos ou mais de idade
-- - pea_10_14 = População economicamente ativa de 10 a 14 anos de idade
-- - pea_15_17 = População economicamente ativa de 15 a 17 anos de idade
-- - pea_18_mais = População economicamente ativa de 18 anos ou mais de idade
-- - pia = População de 10 anos ou mais de idade
-- - pia_10_14 = População de 10 a 14 anos de idade
-- - pia_15_17 = População em idade ativa 15 a 17 anos
-- - pia_18_mais = População de 18 anos ou mais em idade ativa
-- - indice_escolaridade = Subíndice de escolaridade fundamental da população adulta - IDHM Educação
-- - indice_frequencia_escolar = Subíndice de frequência escolar da população jovem - IDHM Educação
-- - idhm = Índice de Desenvolvimento Humano Municipal
-- - idhm_e = Índice de Desenvolvimento Humano Municipal - Dimensão Educação
-- - idhm_l = Índice de Desenvolvimento Humano Municipal - Dimensão Longevidade
-- - idhm_r = Índice de Desenvolvimento Humano Municipal - Dimensão Renda
--
-- **Fonte:** https://basedosdados.org/dataset/cbfc7253-089b-44e2-8825-755e1419efc8?table=65639055-2408-46b4-8f82-ecae3d04b800

-- %%
CREATE OR REPLACE TABLE data_lake_turing_.prata.idh_uf (
SELECT
ano,
sigla_uf,
indice_gini,
renda_pc,
prop_trabalhadores_conta_proria,
prop_empregadores,
prop_ocupados_agropecuaria,
prop_ocupados_comercio,
prop_ocupados_construcao,
prop_ocupados_extracao,
prop_ocupados_formalizacao,
prop_ocupados_fundamental,
prop_ocupados_medio,
prop_ocupados_servicos,
prop_ocupados_siup,
prop_ocupados_superior,
prop_ocupados_transformacao,
taxa_ocupados_carteira,
taxa_ocupados_setor_publico,
taxa_ocupados_sem_carteira,
taxa_agua_encanada,
taxa_energia_eletrica,
taxa_sem_energia_eletrica,
taxa_criancas_fora_escola_4_5,
taxa_criancas_fora_escola_6_14,
populacao,
populacao_urbana,
populacao_rural,
pea_18_mais,
indice_escolaridade,
indice_frequencia_escolar,
idhm,
idhm_e,
idhm_l,
idhm_r
FROM data_lake_turing_.bronze.mundo_onu_idh_uf
WHERE ano >= 2010)
